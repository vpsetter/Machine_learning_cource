# %% [markdown]
# # Построение круговой диаграммы
#
# Выполните построение круговой диаграммы по данным файла Electric_Сars.csv, содержащим сведения о моделях электромобилей.
#
# Для построения диаграммы:
#
# 1.	Сформируйте данные по количеству моделей (столбец Brand) и выполните их сортировку по столбцу TopSpeed_KmH.
#
# 2.	Используйте библиотеку matplotlib, чтобы построить круговую диаграмму по полученным в первом пункте данным. Диаграмма должна показывать долю в процентном отношении первых 5 и всех остальных моделей (rest).
#
# 3.	Покажите на диаграмме наименование брендов и соответствующую им долю в процентах.
#
# 4.	Увеличьте радиус диаграммы в 3 раза.
#
# 5.	Сохраните график под именем auto_pie.png.

# %%
import pandas as pd
import os

import matplotlib.pyplot as plt

# %%
root_path = os.getcwd()
dir_path = os.path.join(root_path, "datasets")
filename = "Electric_car.csv"
file_path = os.path.join(dir_path, filename)

# %%
df = pd.read_csv(file_path)

# %%
df.head(10)
# Out:
#          Brand                          Model  AccelSec  TopSpeed_KmH  \
# 0       Tesla   Model 3 Long Range Dual Motor       4.6           233
# 1  Volkswagen                       ID.3 Pure      10.0           160
# 2    Polestar                               2       4.7           210
# 3         BMW                            iX3        6.8           180
# 4       Honda                              e        9.5           145
# 5       Lucid                            Air        2.8           250
# 6  Volkswagen                         e-Golf        9.6           150
# 7     Peugeot                          e-208        8.1           150
# 8       Tesla     Model 3 Standard Range Plus       5.6           225
# 9        Audi                      Q4 e-tron        6.3           180
#
#    Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 0       450              161            940         Yes        AWD
# 1       270              167            250         Yes        RWD
# 2       400              181            620         Yes        AWD
# 3       360              206            560         Yes        RWD
# 4       170              168            190         Yes        RWD
# 5       610              180            620         Yes        AWD
# 6       190              168            220         Yes        FWD
# 7       275              164            420         Yes        FWD
# 8       310              153            650         Yes        RWD
# 9       400              193            540         Yes        AWD
#
#      PlugType  BodyStyle Segment  Seats  PriceEuro
# 0  Type 2 CCS      Sedan       D      5      55480
# 1  Type 2 CCS  Hatchback       C      5      30000
# 2  Type 2 CCS   Liftback       D      5      56440
# 3  Type 2 CCS        SUV       D      5      68040
# 4  Type 2 CCS  Hatchback       B      4      32997
# 5  Type 2 CCS      Sedan       F      5     105000
# 6  Type 2 CCS  Hatchback       C      5      31900
# 7  Type 2 CCS  Hatchback       B      5      29682
# 8  Type 2 CCS      Sedan       D      5      46380
# 9  Type 2 CCS        SUV       D      5      55000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103 entries, 0 to 102
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Brand            103 non-null    object
#  1   Model            103 non-null    object
#  2   AccelSec         103 non-null    float64
#  3   TopSpeed_KmH     103 non-null    int64
#  4   Range_Km         103 non-null    int64
#  5   Efficiency_WhKm  103 non-null    int64
#  6   FastCharge_KmH   103 non-null    object
#  7   RapidCharge      103 non-null    object
#  8   PowerTrain       103 non-null    object
#  9   PlugType         103 non-null    object
#  10  BodyStyle        103 non-null    object
#  11  Segment          103 non-null    object
#  12  Seats            103 non-null    int64
#  13  PriceEuro        103 non-null    int64
# dtypes: float64(1), int64(5), object(8)
# memory usage: 11.4+ KB

# %%
df.sort_values(by = 'TopSpeed_KmH', ascending = False, inplace = True)
df
# Out:
#           Brand                           Model  AccelSec  TopSpeed_KmH  \
# 51       Tesla                        Roadster        2.1           410
# 59       Tesla              Model S Performance       2.5           261
# 24       Tesla   Model 3 Long Range Performance       3.4           261
# 16     Porsche                   Taycan Turbo S       2.8           260
# 79     Porsche                     Taycan Turbo       3.2           260
# ..          ...                             ...       ...           ...
# 82       Smart                  EQ fortwo coupe      11.6           130
# 77       Smart                      EQ forfour       12.7           130
# 17  Volkswagen                           e-Up!       11.9           130
# 68     Renault                Kangoo Maxi ZE 33      22.4           130
# 66      Nissan                  e-NV200 Evalia       14.0           123
#
#     Range_Km  Efficiency_WhKm FastCharge_KmH RapidCharge PowerTrain  \
# 51       970              206            920         Yes        AWD
# 59       505              188            550         Yes        AWD
# 24       435              167            910         Yes        AWD
# 16       375              223            780         Yes        AWD
# 79       390              215            810         Yes        AWD
# ..       ...              ...            ...         ...        ...
# 82       100              167              -          No        RWD
# 77        95              176              -          No        RWD
# 17       195              166            170         Yes        FWD
# 68       160              194              -          No        FWD
# 66       190              200            190         Yes        FWD
#
#           PlugType  BodyStyle Segment  Seats  PriceEuro
# 51      Type 2 CCS     Cabrio       S      4     215000
# 59          Type 2   Liftback       F      5      96990
# 24      Type 2 CCS      Sedan       D      5      61480
# 16      Type 2 CCS      Sedan       F      4     180781
# 79      Type 2 CCS      Sedan       F      4     148301
# ..             ...        ...     ...    ...        ...
# 82          Type 2  Hatchback       A      2      21387
# 77          Type 2  Hatchback       A      4      22030
# 17      Type 2 CCS  Hatchback       A      4      21421
# 68          Type 2        SPV       N      5      38000
# 66  Type 1 CHAdeMO        SPV       N      7      33246
#
# [103 rows x 14 columns]

# %%
top_counts = df[['Brand', 'Model']].groupby('Brand').count().sort_values(by = 'Model', ascending = False)
top_counts.reset_index(inplace = True)
top_counts
# Out:
#           Brand  Model
# 0        Tesla      13
# 1         Audi       9
# 2       Nissan       8
# 3   Volkswagen       8
# 4        Skoda       6
# 5          Kia       5
# 6      Porsche       5
# 7      Renault       5
# 8          BMW       4
# 9         Ford       4
# 10       Smart       3
# 11    Mercedes       3
# 12        Opel       3
# 13     Hyundai       3
# 14       Byton       3
# 15     Peugeot       2
# 16       Honda       2
# 17        Fiat       2
# 18        SEAT       1
# 19        Sono       1
# 20    Polestar       1
# 21      Aiways       1
# 22          MG       1
# 23        Mini       1
# 24       Mazda       1
# 25       Lucid       1
# 26   Lightyear       1
# 27       Lexus       1
# 28      Jaguar       1
# 29          DS       1
# 30     Citroen       1
# 31       CUPRA       1
# 32       Volvo       1

# %%
full_counts = top_counts['Model'].sum()
full_counts
# Out:
# 103

# %%
categories = list(top_counts['Brand'][:5])
categories.append("Rest")
categories
# Out:
# ['Tesla ', 'Audi ', 'Nissan ', 'Volkswagen ', 'Skoda ', 'Rest']

# %%
values = list(top_counts['Model'][:5] * 100.0 / full_counts)
values.append(top_counts['Model'][5:].sum() * 100.0 / full_counts)
values
# Out:
# [12.62135922330097,
#  8.737864077669903,
#  7.766990291262136,
#  7.766990291262136,
#  5.825242718446602,
#  57.28155339805825]

# %%
plt.pie(values, labels = categories, autopct= lambda x: f"{x :.1f}%")
plt.show()

# %%
plt.pie(values, labels = categories, autopct= lambda x: f"{x :.1f}%", radius = 3)
plt.savefig('auto_pie.png')
plt.show()
